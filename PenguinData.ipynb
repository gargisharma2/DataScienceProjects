# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("penguins_size.csv")

# %%
df.head(5)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
def missing_values_table(df):
    mis_val = df.isna().sum()
    mis_val_percentage = 100 * df.isna().sum() / len(df)
    mis_value_table = pd.concat([mis_val, mis_val_percentage], axis=1)
    mis_value_table.columns = ['Missing Values', '% Missing']
    sorted_missing_values_table = mis_value_table.sort_values(by='Missing Values', ascending=False)
    print(f"Your selected data frame has {df.shape[0]} rows and {df.shape[1]} columns.")
    return sorted_missing_values_table

# %%
missing_values_table(df)
# Out:
# Your selected data frame has 344 rows and 7 columns.
#                    Missing Values  % Missing
# sex                            10   2.906977
# culmen_length_mm                2   0.581395
# culmen_depth_mm                 2   0.581395
# flipper_length_mm               2   0.581395
# body_mass_g                     2   0.581395
# species                         0   0.000000
# island                          0   0.000000

# %%
df[df['culmen_length_mm'].isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df= df.drop([3,339])

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  8
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.species.value_counts().plot(kind='bar',color=['r','g','b'])
# Out:
# <Axes: xlabel='species'>

# %%
df.island.value_counts().plot(kind='line',color=['r','g','b'])
# Out:
# <Axes: xlabel='island'>

# %%
sns.barplot(df['species'])
# Out:
# <Axes: ylabel='species'>

# %%
sns.barplot(df.species)
# Out:
# <Axes: ylabel='species'>

# %%
df.sex.value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
df.sex.value_counts().plot(kind='pie',title="segregation based on sex")
# Out:
# <Axes: title={'center': 'segregation based on sex'}, ylabel='count'>

# %%
sns.displot(data = df,x="island", hue="species")

# %%
sns.displot(data = df,x="island", hue="species",multiple="stack")
